# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://postgres:student@127.0.0.1/idif_pension_db

# %%
# %sql SELECT * FROM dcplandata LIMIT 5;
# Out:
#  * postgresql://postgres:***@127.0.0.1/idif_pension_db
# 5 rows affected.
# [('1', 'AK', 'Alaska PERS \x96 DCR Plan', 2015, '2006.0', 3.0, 'Alaska PERS', '1', 'NaN', '1.0', '1.0', '401(a)', 'Eligible Alaska PERS employees hired after July 1, 2006 are automatically enrolled in the DCR plan. Additionally, certain active members of the DB Plan were eligible to transfer to the DCR Plan if that member had not vested in the DB Plan.', 'NaN', 'NaN', '17456.0', '612212.0', '28', nan, '.08', nan, 'NaN', nan, 0.05, 'NaN', 70462.0, 38949.0, nan),
# ...
